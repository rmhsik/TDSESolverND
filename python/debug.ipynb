# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget

def LoadComplexData(file,**genfromtext_args):
    """
    Load complex data in the C++ format in numpy.
    """
    array_as_strings = np.genfromtxt(file,dtype=str,**genfromtext_args)
    complex_parser = np.vectorize(lambda x: complex(*eval(x)))
    return complex_parser(array_as_strings)

# %%
psi2_start = LoadComplexData('../results/init_psi2.dat')
# psi2_end = np.genfromtxt('../results/itp_psi2.dat')
#potential = LoadComplexData('../results/potential.dat')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_10189/1529773709.py in <module>
# ----> 1 psi2_start = LoadComplexData('../results/init_psi2.dat')
#       2 # psi2_end = np.genfromtxt('../results/itp_psi2.dat')
#       3 #potential = LoadComplexData('../results/potential.dat')
#
# /tmp/ipykernel_10189/2474074368.py in LoadComplexData(file, **genfromtext_args)
#       7     Load complex data in the C++ format in numpy.
#       8     """
# ----> 9     array_as_strings = np.genfromtxt(file,dtype=str,**genfromtext_args)
#      10     complex_parser = np.vectorize(lambda x: complex(*eval(x)))
#      11     return complex_parser(array_as_strings)
#
# ...

# %%
r = np.genfromtxt('../results/i.dat')
z = np.genfromtxt('../results/k.dat')

# %%
potential = potential.reshape((1000,2400))
psi2_start = psi2_start.reshape((1000,2400))

# %%
fig = plt.figure()
ax = fig.subplots(1,1)
ax.imshow(psi2_start.real)
#ax.plot(psi2_end)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
psi2_start
# Out:
# array([0.+0.j, 0.+0.j, 0.+0.j, ..., 0.+0.j, 0.+0.j, 0.+0.j])

# %%
np.abs(z).min()
# Out:
# 0.050020842018

# %%
(z[-1]-z[0])/2400
# Out:
# 0.1

# %%
z[1200-1]
# Out:
# -0.050020842018

# %%
1/np.sqrt(0.05**2 + 0.05**2)
# Out:
# 14.142135623730947

# %%
fig = plt.figure()
ax = fig.subplots(1,1)
ax.plot(z,psi2_start.real[0,:])
ax.set_yscale('log')
#ax.plot(psi2_end)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
psi2_start.shape
# Out:
# (1000, 2400)
